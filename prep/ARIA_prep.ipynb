# %% [markdown]
# # Preparing ARIA Sentinel-1 data for validation of Solid Earth requirements
#
# **Original code authored by:** David Bekaert, Heresh Fattahi, Eric Fielding, and Zhang Yunjun  <br>
# Extensive modifications by Adrian Borsa and Amy Whetter 2022 <br>
# Reorganized and modified by Ekaterina Tymofyeyeva, March 2024
#
# <div class="alert alert-warning">
# This notebook pre-processes data for different NISAR Solid Earth calval sites amd requirements. Subsequent validation is done via separate notebooks for the Transient, Secular, and Coseismic requirements. These are located under /ATBD_main/methods/.
# </div>

# %% [markdown]
# <hr/>
#
# ## Table of Contents: <a id='prep_TOC'></a>
#
# [**Environment Setup**](#setup)
# - [Load Python Packages](#load_packages)
# - [Define CalVal Site and Parameters](#set_calval_params)
# - [Define Directories](#set_directories)
# - [Authentication](#set_authentication)
#
# [**1. Download and Prepare Interferograms**](#prep_ifg)
# - [1.1.  Download Interferograms](#prep_download_ifg)
# - [1.2.  Crop Interferograms](#prep_crop_ifg)
# - [1.3.  Set Up MintPy Configuration file](#prep_setup_config)
# - [1.4.  Load Data into MintPy](#prep_load_data)
#
# <hr/>

# %% [markdown]
# <a id='#setup'></a>
# ## Environment Setup

# %% [markdown]
# ### Load Python Packages <a id='#load_packages'></a>

# %%
import json
import netrc
import os
import subprocess

# %% [markdown]
# ### Define Calval Site and Parameters <a id='set_calval_params'></a>

# %%
# Specify a calval location ID from my_sites.txt
site = 'MojaveA64_3year' 

# Choose the requirement to validate
# Options: 'Secular' 'Coseismic' 'Transient'
requirement = 'Secular' 

# What dataset are you processing?
#'ARIA_S1' (old directory structure for Sentinel-1 testing with aria-tools)
#'ARIA_S1_new' (new directory structure for Sentinel-1 testing with aria-tools)
dataset = 'ARIA_S1_new'
aria_gunw_version = '3_0_1'

# The date and version of this Cal/Val run
rundate = '20250408'
version = '1'

# Provide the file where you keep your customized list of sites.
custom_sites = '/home/jovyan/my_sites.txt'

# Enter a username for storing your outputs
if os.path.exists('/home/jovyan/me.txt'):
    with open('/home/jovyan/me.txt') as m:
        you = m.readline().strip()
else:
    you = input('Please type a username for your calval outputs:')
    with open ('/home/jovyan/me.txt', 'w') as m: 
        m.write(you)

# Load metadata for calval locations
with open(custom_sites,'r') as fid:
    sitedata = json.load(fid)
sitedata['sites'][site]
# Out:
# {'calval_location': 'MojaveA64_3year',
#  'download_region': "'34.50 35.60 -118.8 -116.6'",
#  'analysis_region': "'34.50 35.60 -118.8 -116.6'",
#  'reference_lalo': '34.919,-117.012',
#  'download_start_date': '20170101',
#  'download_end_date': '20200101',
#  'noEarthquakeDate': '20170705',
#  'sentinel_track': '64',
#  'gps_ref_site_name': 'BSRY',
#  'tempBaseMax': 'auto',
#  'ifgExcludeList': 'auto',
#  'do_set_correction': 'False',
#  'do_ion_correction': 'False',
#  'do_tropo_correction': 'False',
#  'tropo_model': 'HRRR_ARIA',
#  'gnss_source': 'UNR',
#  'maskWater': 'False'}

# %% [markdown]
# ### Set Directories and Files <a id='set_directories'></a>

# %%
# Directory location for Cal/Val data (do not change)
start_directory = '/scratch/nisar-st-calval-solidearth' 

# Site directory
site_dir = os.path.join(start_directory, dataset, site)

# Working directory for calval processing
work_dir = os.path.join(site_dir, requirement, you, rundate, 'v' + version)
os.makedirs(work_dir, exist_ok=True)
os.chdir(work_dir)
print("  Work directory:", work_dir)

# Directory for storing GUNW interferograms
gunw_dir = os.path.join(site_dir,'products')
os.makedirs(gunw_dir, exist_ok=True)
print("  GUNW directory:", gunw_dir) 

# Directory for storing MintPy outputs
mintpy_dir = os.path.join(work_dir,'MintPy')
os.makedirs(mintpy_dir, exist_ok=True)
print("MintPy directory:", mintpy_dir)

# Configuration file
config_file = os.path.join(mintpy_dir, sitedata['sites'][site]['calval_location'] + '.cfg')
# Out:
#   Work directory: /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1
#   GUNW directory: /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/products
# MintPy directory: /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/MintPy

# %% [markdown]
# ### Authentication <a id='set_authentication'></a>

# %%
# Earthdata login to download GUNWs
fnetrc = '/home/jovyan/.netrc'
earthdata = False
if os.path.exists(fnetrc):
    os.system('chmod 0600 ' + fnetrc)
    remoteHostName  = "urs.earthdata.nasa.gov"
    netrc = netrc.netrc()
    with open(fnetrc) as file:
        if remoteHostName in file.read():
            authTokens = netrc.authenticators(remoteHostName)
            earthdata_user = authTokens[0]
            earthdata_password = authTokens[2]
            earthdata = True          
if not earthdata:             
    print('NEEDED to Download ARIA GUNWs: \n Link to create account : https://urs.earthdata.nasa.gov/')
    earthdata_user = input('Please type your Earthdata username:')
    earthdata_password = input('Please type your Earthdata password:')
    with open(fnetrc, 'a') as file:
        file.write('machine urs.earthdata.nasa.gov\n')
        file.write('login ' + earthdata_user + '\n')
        file.write('password ' + earthdata_password)
        os.system('chmod 0600 ' + fnetrc)

# OpenTopography login to download DEMs
fopentopo = '/home/jovyan/.topoapi'
if os.path.exists(fopentopo):
    os.system('chmod 0600 ' + fopentopo)
    with open(fopentopo) as file:
        opentopography_api_key = file.read()
else:   
    print('NEEDED To Download DEMs: \n Link to get API Key : https://portal.opentopography.org/login' + 
     '\n Goto: My Account > myOpenTopo Authorizations and API Key > Request API key')
    opentopography_api_key = input('Please type your OpenTopo API key:')
    with open(fopentopo, 'a') as file:
        file.write(opentopography_api_key)
        os.system('chmod 0600 ' + fopentopo)

# %% [markdown]
# <br>
# <hr>
#
# <a id='prep_ifg'></a>
# ## 1. Download and Prepare Interferograms
#
# In this initial processing step, all the necessary Level-2 unwrapped interferogram products are gathered, organized and reduced to a common grid for analysis with MintPy. Ascending and descending stacks of nearest-neighbor and skip-1 interferograms will be prepared for independent analysis. We use the open-source ARIA-tools package to download processed L2 interferograms over selected cal/val regions from the Alaska Satellite Facility archive and to stitch/crop the frame-based NISAR GUNW products to stacks that can be directly ingested into MintPy for time-series processing. ARIA-tools uses a phase-minimization approach in the product overlap region to stitch the unwrapped and ionospheric phase, a mosaicing approach for coherence and amplitude, and extracts the geometric information from the 3D data cubes through a mosaicking of the 3D datacubes and subsequent intersection with a DEM.
#
# REFERENCE: https://github.com/aria-tools/ARIA-tools

# %% [markdown]
# ### 1.1. Download GUNW Interferograms <a id='prep_download_ifg'></a>

# %%
print('CalVal site: {}'.format(site))
bbox = sitedata['sites'][site]['download_region']
startdate = sitedata['sites'][site]['download_start_date']
enddate = sitedata['sites'][site]['download_end_date']
track = sitedata['sites'][site]['sentinel_track']

# Make general ARIA_download command
aria_download = 'ariaDownload.py --num_threads 8 -b {bbox} -u {user} -p "{password}" \
    -s {start}  -e {end} -t {track} --workdir {workdir} --version {version} -o {output}'

# Use ARIA_download to count number of archived GUNW files
command = aria_download.format(bbox = bbox, start = startdate, end = enddate,
                                track = track, version = aria_gunw_version, 
                                user = earthdata_user, password = earthdata_password, 
                                workdir = gunw_dir, output = 'count')
process = subprocess.run(command, text = True, shell = True, \
    stdout=subprocess.PIPE, stderr=subprocess.PIPE)
print(process.stderr.split('\n')[-2])

# Use ARIA_download to generate list of GUNW URLs 
command = aria_download.format(bbox = bbox, start = startdate, end = enddate,
                                track = track, version = aria_gunw_version, 
                                user = earthdata_user, password = earthdata_password, 
                                workdir = gunw_dir, output = 'Url')
process = subprocess.run(command, text = True, shell = True, \
    stdout=subprocess.PIPE, stderr=subprocess.PIPE)

# Use ARIA_download to download GUNWs
print('Starting GUNW download....')
command = aria_download.format(bbox = bbox, start = startdate, end = enddate,
                                track = track, version = aria_gunw_version, 
                                user = earthdata_user, password = earthdata_password, 
                                workdir = gunw_dir, output = 'Download')
process = subprocess.run(command, text = True, shell = True, \
    stdout=subprocess.PIPE, stderr=subprocess.PIPE)
print('Finished GUNW download')

# Cleaning unnecessary files
data_to_clean = ["avg_rates.csv", "ASFDataDload0.py", "AvgDlSpeed.png", "error.log"]
for i, file in enumerate(data_to_clean):
    if os.path.exists(os.path.join(gunw_dir,file)):
        print('Cleaning file {}'.format(file))
        os.unlink(os.path.join(gunw_dir,file))
        os.unlink(os.path.join(work_dir,file))
# Out:
# CalVal site: MojaveA64_3year
# 2025-04-09 02:16:43,597 - ariaDownload.py - INFO - Found -- 2118 -- products
# Starting GUNW download....
# Finished GUNW download

# %% [markdown]
# ### 1.2. Crop and Mask Interferograms <a id='prep_crop_ifg'></a>

# %%
# Identify subset of available GUNW files within user-specified period
startdate = int(sitedata['sites'][site]['download_start_date'])
enddate = int(sitedata['sites'][site]['download_end_date'])
gunw_list = []
for file in os.listdir(gunw_dir):
    if file.endswith('.nc') and file.find(aria_gunw_version) != -1:
        date1 = file[30:38]
        date2 = file[21:29]
        if int(date1) >= startdate and int(date2) <= enddate:
            gunw_list.append(os.path.join(gunw_dir, file))

# Write GUNW list to file to pass to ariaTSsetup.py
gunw_list.sort()
product_file = f"{work_dir}/product_file.txt"
with open(product_file, "w") as prod_file:
    prod_file.write("\n".join(map(str, gunw_list)))

# Crop interferograms to analysis region and optionally mask data with GSHHS water mask
os.chdir(work_dir)
mask_file = 'auto'
if not os.path.exists(os.path.join(work_dir,'stack')):
    if not os.path.exists('/home/jovyan/.topoapi'): # if OpenTopo API key not already installed
        os.system('echo "{api_key}" > /home/jovyan/.topoapi; \
            chmod 600 /home/jovyan/.topoapi'.format(api_key = str(opentopography_api_key)))
    print('Preparing GUNWs for MintPY....')
    if sitedata['sites'][site]['maskWater'] != 'False':
        command = 'ariaTSsetup.py -f ' + product_file + ' -b ' + \
            sitedata['sites'][site]['analysis_region'] + \
            ' --mask Download -l "ionosphere, troposphereTotal" --tropo_models HRRR --croptounion -nt 8 --verbose'
        mask_file = '../mask/watermask.msk'
    else: # skip slow mask download when we don't need to mask water
        command = 'ariaTSsetup.py -f ' + product_file + ' -b ' + \
            sitedata['sites'][site]['analysis_region'] + ' -l "ionosphere, troposphereTotal" --tropo_models HRRR --croptounion -nt 8 --verbose'
    # Crop and prepare stack
    process = subprocess.run(command, text = True, shell = True, \
        stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print('Finished preparing GUNWs for MintPy!!')
else:
    print('Stack directory detected and not overwritten.')
# Out:
# Stack directory detected and not overwritten.

# %% [markdown]
# ### 1.3. Set Up MintPy Configuration file <a id='prep_setup_config'></a>
#
# The default processing parameters for MintPy's **smallbaselineApp.py** need to be modified by including the following lines in config_file (which must be manually created and placed into mint_dir):
#
# - mintpy.load.processor      = aria
# - mintpy.load.unwFile        = ../stack/unwrapStack.vrt
# - mintpy.load.corFile        = ../stack/cohStack.vrt
# - mintpy.load.connCompFile   = ../stack/connCompStack.vrt
# - mintpy.load.demFile        = ../DEM/SRTM_3arcsec.dem
# - mintpy.load.incAngleFile   = ../incidenceAngle/{download_start_date}_{download_edn_date}.vrt
# - mintpy.load.azAngleFile    = ../azimuthAngle/{download_start_date}_{download_edn_date}.vrt
# - mintpy.load.waterMaskFile  = ../mask/watermask.msk
# - mintpy.reference.lalo      = auto, or somewhere in your bounding box
# - mintpy.topographicResidual.pixelwiseGeometry = no
# - mintpy.troposphericDelay.method              = no
# - mintpy.topographicResidual                   = no

# %%
os.chdir(mintpy_dir)

# Write smallbaseline.py config file
config_file_content = """
mintpy.load.processor = aria
mintpy.compute.cluster   = local
mintpy.compute.numWorker = auto
mintpy.load.unwFile = {wd}/stack/unwrapStack.vrt
mintpy.load.corFile = {wd}/stack/cohStack.vrt
mintpy.load.connCompFile = {wd}/stack/connCompStack.vrt
mintpy.load.demFile = {wd}/DEM/glo_90.dem
mintpy.load.incAngleFile = {wd}/incidenceAngle/*.vrt
mintpy.load.azAngleFile = {wd}/azimuthAngle/*.vrt
mintpy.load.waterMaskFile = {mask_file}
mintpy.topographicResidual.pixelwiseGeometry = no
mintpy.troposphericDelay.method = no
mintpy.topographicResidual = no
mintpy.network.tempBaseMax = {tempmax}
mintpy.network.startDate = {startdatenet}
mintpy.network.endDate = {enddatenet}
mintpy.velocity.startDate = {startdatevel}
mintpy.velocity.endDate = {enddatevel}
mintpy.reference.lalo = {reference_lalo}
mintpy.network.excludeIfgIndex = {excludeIfg}""".format(wd = work_dir,
                                mask_file = mask_file,
                                tempmax=sitedata['sites'][site]['tempBaseMax'],
                                excludeIfg=sitedata['sites'][site]['ifgExcludeList'],
                                startdatenet=sitedata['sites'][site]['download_start_date'],
                                enddatenet=sitedata['sites'][site]['download_end_date'],
                                startdatevel=sitedata['sites'][site]['download_start_date'],
                                enddatevel=sitedata['sites'][site]['download_end_date'],
                                reference_lalo=sitedata['sites'][site]['reference_lalo'])

# Write the config file
with open(config_file, "w") as file:
    file.write(config_file_content)

# Print the results
print(f'MintPy config file:\n    {config_file}')
with open(config_file, "r") as file:
    print(file.read())
# Out:
# MintPy config file:
#     /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/MintPy/MojaveA64_3year.cfg
#
# mintpy.load.processor = aria
# mintpy.compute.cluster   = local
# mintpy.compute.numWorker = auto
# mintpy.load.unwFile = /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/stack/unwrapStack.vrt
# mintpy.load.corFile = /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/stack/cohStack.vrt
# mintpy.load.connCompFile = /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/stack/connCompStack.vrt
# mintpy.load.demFile = /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/DEM/glo_90.dem
# mintpy.load.incAngleFile = /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/incidenceAngle/*.vrt
# mintpy.load.azAngleFile = /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/azimuthAngle/*.vrt
# mintpy.load.waterMaskFile = auto
# mintpy.topographicResidual.pixelwiseGeometry = no
# mintpy.troposphericDelay.method = no
# mintpy.topographicResidual = no
# mintpy.network.tempBaseMax = auto
# mintpy.network.startDate = 20170101
# mintpy.network.endDate = 20200101
# mintpy.velocity.startDate = 20170101
# mintpy.velocity.endDate = 20200101
# mintpy.reference.lalo = 34.919,-117.012
# mintpy.network.excludeIfgIndex = auto

# %% [markdown]
# ### 1.4. Load Data into MintPy Cubes <a id='prep_load_data'></a>
#
# The output of this step is an "inputs" directory in 'calval_directory/calval_location/MintPy/" containing two HDF5 files:
# - ifgramStack.h5: This file contains 6 dataset cubes (e.g. unwrapped phase, coherence, connected components etc.) and multiple metadata
# - geometryGeo.h5: This file contains geometrical datasets (e.g., incidence/azimuth angle, masks, etc.)

# %%
command = 'smallbaselineApp.py ' + str(config_file) + ' --dostep load_data'
process = subprocess.run(command, shell=True)
print('Mintpy input files:')
[x for x in os.listdir('inputs') if x.endswith('.h5')]
# Out:
# /home/jovyan/.local/envs/solid_earth_atbd_dev/lib/python3.13/site-packages/osgeo/gdal.py:311: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
# MintPy version 1.6.1, date 2024-07-31
# --RUN-at-2025-04-09 02:17:24.502435--
# Current directory: /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/MintPy
# Run routine processing with smallbaselineApp.py on steps: ['load_data']
# Remaining steps: ['modify_network', 'reference_point', 'quick_overview', 'correct_unwrap_error', 'invert_network', 'correct_LOD', 'correct_SET', 'correct_ionosphere', 'correct_troposphere', 'deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: MojaveA64_3year
# Go to work directory: /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/MintPy
# copy default template file /home/jovyan/dev/MintPy/src/mintpy/defaults/smallbaselineApp.cfg to work directory
# read custom template file: /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/MintPy/MojaveA64_3year.cfg
# update default template based on input custom template
#     mintpy.compute.cluster: auto --> local
#     mintpy.load.processor: auto --> aria
#     mintpy.load.unwFile: auto --> /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/stack/unwrapStack.vrt
#     mintpy.load.corFile: auto --> /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/stack/cohStack.vrt
#     mintpy.load.connCompFile: auto --> /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/stack/connCompStack.vrt
#     mintpy.load.demFile: auto --> /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/DEM/glo_90.dem
#     mintpy.load.incAngleFile: auto --> /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/incidenceAngle/*.vrt
#     mintpy.load.azAngleFile: auto --> /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/azimuthAngle/*.vrt
#     mintpy.network.startDate: auto --> 20170101
#     mintpy.network.endDate: auto --> 20200101
#     mintpy.reference.lalo: auto --> 34.919,-117.012
#     mintpy.troposphericDelay.method: auto --> no
#     mintpy.topographicResidual: auto --> no
#     mintpy.topographicResidual.pixelwiseGeometry: auto --> no
# copy MojaveA64_3year.cfg  to inputs   directory for backup.
# copy smallbaselineApp.cfg to inputs   directory for backup.
# copy MojaveA64_3year.cfg  to pic      directory for backup.
# copy smallbaselineApp.cfg to pic      directory for backup.
# read default template file: /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/MintPy/smallbaselineApp.cfg
#
#
# ******************** step - load_data ********************
#
# load_data.py --template /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/MintPy/smallbaselineApp.cfg /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/MintPy/MojaveA64_3year.cfg --project MojaveA64_3year
# processor : aria
# SAR platform/sensor : unknown from project name "MojaveA64_3year"
# --------------------------------------------------
# prepare metadata files for aria products
# prep_aria.py --template /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/MintPy/smallbaselineApp.cfg --stack-dir /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/stack --unwrap-stack-name unwrapStack.vrt --coherence-stack-name cohStack.vrt --conn-comp-stack-name connCompStack.vrt --dem /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/DEM/glo_90.dem --incidence-angle "/scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/incidenceAngle/*.vrt" --azimuth-angle "/scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/azimuthAngle/*.vrt" --update
# read options from template file: smallbaselineApp.cfg
# multilook x/ystep: 1/1
# multilook method : nearest
# search input data file info:
# unwFile       : /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/stack/unwrapStack.vrt
# corFile       : /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/stack/cohStack.vrt
# connCompFile  : /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/stack/connCompStack.vrt
# demFile       : /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/DEM/glo_90.dem
# incAngleFile  : /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/incidenceAngle/20180221_20170813.vrt
# azAngleFile   : /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/azimuthAngle/20180221_20170813.vrt
# update mode: True
# extract metadata from /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/stack/unwrapStack.vrt
# --------------------------------------------------
# create HDF5 file: ./inputs/ifgramStack.h5 with w mode
# create dataset  : date             of |S8                       in size of (545, 2)             with compression = False
# create dataset  : dropIfgram       of <class 'numpy.bool'>      in size of (545,)               with compression = False
# create dataset  : bperp            of <class 'numpy.float32'>   in size of (545,)               with compression = False
# create dataset  : unwrapPhase      of <class 'numpy.float32'>   in size of (545, 1321, 2641)    with compression = False
# create dataset  : coherence        of <class 'numpy.float32'>   in size of (545, 1321, 2641)    with compression = False
# create dataset  : connectComponent of <class 'numpy.int16'>     in size of (545, 1321, 2641)    with compression = lzf
# close  HDF5 file: ./inputs/ifgramStack.h5
# --------------------------------------------------
# open unwrapStack.vrt   with gdal ...
# open cohStack.vrt      with gdal ...
# open connCompStack.vrt with gdal ...
# grab NoDataValue for unwrapStack.vrt  : 0.0   and convert to 0.
# grab NoDataValue for cohStack.vrt     : 0.0   and convert to 0.
# grab NoDataValue for connCompStack.vrt: -1.0  and convert to 0.
# number of interferograms: 545
# writing data to HDF5 file ./inputs/ifgramStack.h5 with a mode ...
# [>                                                 ]dict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [>                                                 ]dict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [>                                                 ]dict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [>                                                 ]dict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [>                                                 ]dict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [>                                                 ]dict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [>                                                 ]dict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [>                                                 ]dict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [>
/    56sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 94% ==================>   ] 20191008_20191014 511/545  881s /    56sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 94% ==================>   ] 20191008_20191020 512/545  883s /    56sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 94% ==================>   ] 20191008_20191026 513/545  885s /    56sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 94% ==================>   ] 20191014_20191020 514/545  887s /    56sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 94% ==================>   ] 20191014_20191026 515/545  888s /    56sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 95% ===================>  ] 20191014_20191101 516/545  890s /    46sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 95% ===================>  ] 20191020_20191026 517/545  892s /    46sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 95% ===================>  ] 20191020_20191101 518/545  893s /    47sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 95% ===================>  ] 20191020_20191107 519/545  895s /    47sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 95% ===================>  ] 20191026_20191101 520/545  897s /    47sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 96% ===================>  ] 20191026_20191107 521/545  899s /    37sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 96% ===================>  ] 20191026_20191113 522/545  900s /    37sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 96% ===================>  ] 20191101_20191107 523/545  902s /    37sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 96% ===================>  ] 20191101_20191113 524/545  905s /    37sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 96% ===================>  ] 20191101_20191119 525/545  907s /    37sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 97% ===================>  ] 20191107_20191113 526/545  908s /    28sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 97% ===================>  ] 20191107_20191119 527/545  910s /    28sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 97% ===================>  ] 20191107_20191125 528/545  912s /    28sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 97% ===================>  ] 20191113_20191119 529/545  914s /    28sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 97% ===================>  ] 20191113_20191125 530/545  916s /    28sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 97% ===================>  ] 20191113_20191201 531/545  918s /    28sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 98% ====================> ] 20191119_20191125 532/545  919s /    18sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 98% ====================> ] 20191119_20191201 533/545  921s /    18sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 98% ====================> ] 20191119_20191207 534/545  923s /    18sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 98% ====================> ] 20191125_20191201 535/545  925s /    18sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [======================= 98% ====================> ] 20191125_20191207 536/545  926s /    18sdict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [==================================================] 20191125_20191213 537/545dict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [==================================================] 20191201_20191207 538/545dict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [==================================================] 20191201_20191213 539/545dict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [==================================================] 20191207_20191213 540/545dict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [==================================================] 20191207_20191225 541/545dict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [==================================================] 20191207_20191231 542/545dict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [==================================================] 20191213_20191225 543/545dict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [==================================================] 20191213_20191231 544/545dict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
# [==================================================] 20191225_20191231 545/545dict_keys(['unwrapPhase', 'coherence', 'connectComponent'])
#
# finished writing to HD5 file: ./inputs/ifgramStack.h5
#
# --------------------------------------------------
# create HDF5 file: ./inputs/geometryGeo.h5 with w mode
# create dataset  : height             of <class 'numpy.float32'>   in size of (1321, 2641)         with compression = False
# create dataset  : incidenceAngle     of <class 'numpy.float32'>   in size of (1321, 2641)         with compression = False
# create dataset  : slantRangeDistance of <class 'numpy.float32'>   in size of (1321, 2641)         with compression = False
# create dataset  : azimuthAngle       of <class 'numpy.float32'>   in size of (1321, 2641)         with compression = False
# close  HDF5 file: ./inputs/geometryGeo.h5
# --------------------------------------------------
# writing data to HDF5 file ./inputs/geometryGeo.h5 with a mode ...
# finished writing to HD5 file: ./inputs/geometryGeo.h5
#
# --------------------------------------------------
# time used: 15 mins 47.2 secs.
# No lookup table (longitude or rangeCoord) found in files.
# Input data seems to be geocoded. Lookup file not needed.
# Loaded dataset are processed by InSAR software: isce
# Loaded dataset are in GEO coordinates
# Interferogram Stack: /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/MintPy/inputs/ifgramStack.h5
# Geometry      File : /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/MintPy/inputs/geometryGeo.h5
# Lookup Table  File : None
# --------------------------------------------------
# updating metadata based on custom template file MojaveA64_3year.cfg for file: ifgramStack.h5
# Go back to directory: /scratch/nisar-st-calval-solidearth/ARIA_S1_new/MojaveA64_3year/Secular/rzinke/20250408/v1/MintPy
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 15 mins 55.3 secs
#
# Mintpy input files:
# ['geometryGeo.h5', 'ifgramStack.h5']
